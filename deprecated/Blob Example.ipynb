# %% [markdown]
# ###Blobs. A project of Urban CCD in Chicago
# #Tutorial 1.0 - Using Static Data

# %% [markdown]
# ##Data Prep and Set-Up
#    You should have already cloned the blobs repo from GitHub, and saved it accordingly. The first steps import the required libraries, assign and initilize the required data and spatial files. Your data will be connected to spatial files, connecting 311 call data to census tracts in this case.

# %%
# Import required libraries
import blobs
import numpy as np
import pandas as pd
import pysal as ps

# %%
cd ..
# Out:
# /Users/jiajunshen/Documents/blobs

# %%
# Open census tract shapefile and database.
shp_link = 'tracts/CensusTractsTIGER2010.shp'
dbf = ps.open('tracts/CensusTractsTIGER2010.dbf')

# %%
# Shapefile and data preparation.
cols = np.array([dbf.by_col(col) for col in dbf.header]).T
df = pd.DataFrame(cols)
df.columns = dbf.header
df.columns = df.columns.map(lambda x: x.lower())
df.commarea = df.commarea.astype('int')
df['order'] = df.index

# %%
# Assign spatial weight for census tracts.
w=ps.open('tracts/CensusTractsTIGER2010.gal').read()

# %%
# Initialize sample 311 call data from CSV file.
init_calls = pd.read_csv('master311.csv', dtype=object)
for c in init_calls.columns[1:]:
    init_calls[c] = init_calls[c].astype('float')

# %%
# Format data and merge on shapefile IDs
ordered_tracts = pd.DataFrame(df.loc[:,['tractce10', 'commarea', 'order']])
calls = pd.merge(init_calls, ordered_tracts, how='right', left_on='tractID', 
    right_on='tractce10', sort=False).fillna(0).sort(['order'])
calls = calls.drop(['order', 'commarea'],1)

class bd:
  data = calls
  w = w
  shp_link = shp_link
  id = 'tractce10'
  level = 'tract'

# %%
# Assign the attribute data.
d = bd()

# %% [markdown]
# ##Create Blobs
# You can assign what attribute you would like to "blob" accordingly. In example 1, blobs are created from census tracts and must have a minimum of 10,000 persons per blob.

# %%
# Example 1: Create blobs minimum population of 10,000 in each blob. This calls a Pop-Up Window with the Map.
b = blobs.Blobs(d, 'pop', 10000, iterations=1)
# Out:
# ['vehicles_per1000', 'alley_lights_per1000', 'garbage_per1000', 'graffiti_per1000', 'potholes_per1000', 'rodents_per1000', 'sanitation_per1000', 'street_lights_one_per1000', 'street_lights_all_per1000', 'tree_debris_per1000', 'tree_trims_per1000', 'buildings_per1000', 'all_calls_per1000']
#
# ### CREATING BLOBS FROM 13 VARIABLES ###
#     PARAMETERS:
#      # Minimum pop in each blob: 10000
#      # Iterations: 1
#      # Method: equal votes
#      # Plot blobs: True
#      # Save blobs data: False
#
#
# # ITERATION 1
#   Score: 3045.44
#   Created 183 blobs (4 tracts per blob)
#   Best solution so far: 3045.44
#   Time taken: 5.5 seconds (0 seconds remaining)
# # BEST SOLUTION:
#   Score: 3045.44
#   183 blobs (4 tracts per blob)
#   Plotting...

# %%
# Cluster the blobs along similarities in the data
cl = blobs.Cluster_blobs(b, blobs_per_cluster=10)

# %%
# See the cluster assignment for each blob
cl.assignments
# Out:
# array([ 3,  0, 14,  3,  6,  5,  3, 12,  0, 13,  5,  1,  0,  3, 15, 10, 15,
#         4, 15,  0,  5,  9, 10, 14,  0,  2,  3,  3,  2,  8,  7,  9,  3,  5,
#         3,  0,  0,  3,  1,  2, 13, 15,  1, 15, 15,  5,  2, 15,  0, 12,  5,
#         5,  4,  1,  6, 12,  0,  8, 16,  0,  3, 10, 10,  4,  6, 15,  0,  0,
#         5, 10,  5,  5, 16,  0,  2,  0,  3,  0,  0,  0, 17, 15,  5, 13,  0,
#        14,  9,  5, 11, 14,  6,  5,  4, 10,  3, 10,  3,  9,  3, 10,  0, 17,
#         3,  8,  0,  5,  9, 10, 15,  1,  5,  5, 14, 15,  2, 15,  0,  6, 13,
#         9,  5, 15, 15,  7, 15, 14,  2, 10,  0,  2,  9,  0,  9, 14,  9,  7,
#        15, 15,  5,  3, 14,  3, 15,  3, 10,  4,  5, 15,  8, 15,  6,  5, 11,
#        13,  5,  9,  1,  1, 11,  9, 14, 14,  9,  5,  1,  9,  5,  1, 15, 15,
#        13, 10, 10,  0, 10,  5,  3, 15,  3,  0, 15,  8,  8], dtype=int32)

# %%
#visualize the blobs after clustering. Blobs within a cluster have same color.
cl.plot_map()

# %% [markdown]
# You can assign what attribute you would like to "blob" accordingly. In example 2, blobs are created from census tracts and must have a minimum of 30 census tracts per blob.

# %%
# Create blobs with a minimum of 30 tracts in each blob, and cluster
b = blobs.Blobs(d, 'areas', 30,iterations=2)
cl = blobs.Cluster_blobs(b, blobs_per_cluster=4)
# Out:
# ['vehicles_per1000', 'alley_lights_per1000', 'garbage_per1000', 'graffiti_per1000', 'potholes_per1000', 'rodents_per1000', 'sanitation_per1000', 'street_lights_one_per1000', 'street_lights_all_per1000', 'tree_debris_per1000', 'tree_trims_per1000', 'buildings_per1000', 'all_calls_per1000']
#
# ### CREATING BLOBS FROM 13 VARIABLES ###
#     PARAMETERS:
#      # Minimum areas in each blob: 30
#      # Iterations: 2
#      # Method: equal votes
#      # Plot blobs: True
#      # Save blobs data: False
#
#
# # ITERATION 1
#   Score: 5782.3
#   Created 21 blobs (38 tracts per blob)
#   Best solution so far: 5782.3
#   Time taken: 19.5 seconds (19 seconds remaining)
# # ITERATION 2
#   Score: 5639.8
#   Created 22 blobs (36 tracts per blob)
#   Best solution so far: 5639.8
#   Time taken: 18.8 seconds (0 seconds remaining)
# # BEST SOLUTION:
#   Score: 5639.8
#   22 blobs (36 tracts per blob)
#   Plotting...

# %%
# See blob assignments
cl.assignments
# Out:
# array([3, 2, 0, 4, 2, 4, 4, 0, 3, 1, 4, 1, 0, 0, 0, 4, 0, 3, 2, 0, 1, 4], dtype=int32)

# %%
# Plot blobs along one of the variables
b.plot_blobs('all_calls_per1000_mean')
# Out:
#   Plotting...

# %%
#visualize the blobs after clustering. Blobs within a cluster have same color.
cl.plot_map()
